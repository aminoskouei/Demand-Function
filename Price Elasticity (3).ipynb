# %% [markdown]
# # Price Elasticity

# %% [markdown]
# ### Read the data

# %%
# Load the Pandas libraries with alias 'pd' 
import pandas as pd 
import math
from sklearn.linear_model import LinearRegression
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
AllSKU = pd.read_csv("C:/Users/amin.oskouei/Desktop/PE-all-SKU/All-200-SKU.csv")
# Preview the first 5 lines of the loaded data 
AllSKU.head()
# Out:
#                 sku   full_date  total_qty  avg_list_price  avg_discount_rate  \
# 0    200SHG1-53076O  2018-05-07        1.0          179.00                0.5
# 1  200SPRE40B-76096  2018-05-07        1.0          489.00                0.5
# 2  200NCCL01-960136  2018-05-07        1.0          819.00                0.5
# 3  200JAPD1A-860116  2018-05-07        9.0           79.00                0.0
# 4   200XMP22684-508  2018-05-07        1.0           49.99                0.2
#
#    avg_paid_price
# 0           89.00
# 1          244.00
# 2          409.00
# 3           79.00
# 4           39.99

# %%
SKUID = pd.read_csv("C:/Users/amin.oskouei/Desktop/Top 10 SKU PE/PriceQunt/Top10SKU-ID.csv")
SKUID.head()
# Out:
#                    sku  code
# 0  200RZBD16A-71001010     1
# 1      200RZBD16A-6709     2
# 2     200RZBD16A-53079     3
# 3      200RZBD16A-2808     4
# 4       200RZBD16A-406     5

# %%
sales = AllSKU.loc[(AllSKU['total_qty'] > 1)]
sales.head()
# Out:
#                  sku   full_date  total_qty  avg_list_price  \
# 3   200JAPD1A-860116  2018-05-07        9.0            79.0
# 6     200BDSM04A-203  2018-05-07        2.0            39.0
# 17    200HMCO4C-9012  2018-05-07        2.0           349.0
# 25     200ON01A-8010  2018-05-07        5.0           469.0
# 30   200TAJT09E-2608  2018-05-07        2.0            99.0
#
#     avg_discount_rate  avg_paid_price
# 3                0.00            79.0
# 6                0.41            23.0
# 17               0.40           209.0
# 25               0.46           252.8
# 30               0.40            59.5

# %%
# Python program explaining 
# log() function 
import numpy as np 

logqty = np.log(sales['total_qty'])
logprice = np.log(sales['avg_paid_price'])
sales['logqty'] = logqty
sales['logprice'] = logprice
sales.head()
# Out:
# C:\Users\amin.oskouei\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\amin.oskouei\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                  sku   full_date  total_qty  avg_list_price  \
# 3   200JAPD1A-860116  2018-05-07        9.0            79.0
# 6     200BDSM04A-203  2018-05-07        2.0            39.0
# 17    200HMCO4C-9012  2018-05-07        2.0           349.0
# 25     200ON01A-8010  2018-05-07        5.0           469.0
# 30   200TAJT09E-2608  2018-05-07        2.0            99.0
#
#     avg_discount_rate  avg_paid_price    logqty  logprice
# 3                0.00            79.0  2.197225  4.369448
# 6                0.41            23.0  0.693147  3.135494
# 17               0.40           209.0  0.693147  5.342334
# 25               0.46           252.8  1.609438  5.532599
# 30               0.40            59.5  0.693147  4.085976

# %% [markdown]
# ### Extracting subset and do regression :

# %% [markdown]
# #### How merge data-set in Panda: https://chrisalbon.com/python/data_wrangling/pandas_join_merge_dataframe/

# %%
sales_inner = pd.merge(sales, SKUID, on='sku', how='left')
sales_inner.head()
# Out:
#                 sku   full_date  total_qty  avg_list_price  avg_discount_rate  \
# 0  200JAPD1A-860116  2018-05-07        9.0            79.0               0.00
# 1    200BDSM04A-203  2018-05-07        2.0            39.0               0.41
# 2    200HMCO4C-9012  2018-05-07        2.0           349.0               0.40
# 3     200ON01A-8010  2018-05-07        5.0           469.0               0.46
# 4   200TAJT09E-2608  2018-05-07        2.0            99.0               0.40
#
#    avg_paid_price    logqty  logprice   code
# 0            79.0  2.197225  4.369448    NaN
# 1            23.0  0.693147  3.135494  100.0
# 2           209.0  0.693147  5.342334    NaN
# 3           252.8  1.609438  5.532599    NaN
# 4            59.5  0.693147  4.085976    NaN

# %% [markdown]
# ### ln - ln simple regression

# %%
from sklearn import linear_model
for i in range (1,128):
        
        subset_data = sales_inner.loc[(sales_inner['code'] == i)]
        
        reg = linear_model.LinearRegression()
        reg.fit(subset_data[['logprice']], subset_data['logqty'])
        print(SKUID.loc[(SKUID['code'] == i),"sku"], reg.coef_)

for i in range (129,137):
        
        subset_data = sales_inner.loc[(sales_inner['code'] == i)]
        reg = linear_model.LinearRegression()
        reg.fit(subset_data[['logprice']], subset_data['logqty'])
        print(SKUID.loc[(SKUID['code'] == i),"sku"], reg.coef_)
# Out:
# 0    200RZBD16A-71001010
# Name: sku, dtype: object [-4.75925075]
# 1    200RZBD16A-6709
# Name: sku, dtype: object [-4.14038199]
# 2    200RZBD16A-53079
# Name: sku, dtype: object [-3.35211129]
# 3    200RZBD16A-2808
# Name: sku, dtype: object [-1.43679542]
# 4    200RZBD16A-406
# Name: sku, dtype: object [-1.78414537]
# 5    200RZBD16A-9012
# Name: sku, dtype: object [-2.17506446]
# 6    200RZBD16A-203
# Name: sku, dtype: object [-1.57488585]
# 7    200RZBD16A-305
# Name: sku, dtype: object [-1.11826464]
# 8    200RZBD16A-28012
# Name: sku, dtype: object [-0.8739697]
# 9    200RZBD16A-10014
# Name: sku, dtype: object [-1.10448704]
# 10    200RZBD16A-505R
# Name: sku, dtype: object [-0.86289031]
# 11    200RZBD16A-808S
# Name: sku, dtype: object [-0.57252522]
# 12    200RZBD16A-12015
# Name: sku, dtype: object [-0.68845394]
# 13    200RZBD16A-7100710R
# Name: sku, dtype: object [-0.4752408]
# 14    200RZBD16A-28020
# Name: sku, dtype: object [-0.13572497]
# 15    200RZBD16A-6709O
# Name: sku, dtype: object [0.02659241]
# 16    200RZBD07A-71001010
# Name: sku, dtype: object [-1.77643131]
# 17    200RZBD07A-53079
# Name: sku, dtype: object [-1.43566676]
# 18    200RZBD07A-6709
# Name: sku, dtype: object [-0.88686877]
# 19    200RZBD07A-203
# Name: sku, dtype: object [-0.36658022]
# 20    200RZBD07A-2808
# Name: sku, dtype: object [-0.44840689]
# 21    200RZBD07A-406
# Name: sku, dtype: object [-0.30285173]
# 22    200RZBD07A-305
# Name: sku, dtype: object [-0.82491064]
# 23    200RZBD07A-9012
# Name: sku, dtype: object [-1.27553187]
# 24    200RZBD07A-505R
# Name: sku, dtype: object [-0.75178413]
# 25    200RZBD07A-28012
# Name: sku, dtype: object [-0.39383481]
# 26    200RZBD07A-7100710R
# Name: sku, dtype: object [-1.20286635]
# 27    200RZBD07A-10014
# Name: sku, dtype: object [-0.30890949]
# 28    200RZBD07A-808S
# Name: sku, dtype: object [0.04539217]
# 29    200RZBD07A-12015
# Name: sku, dtype: object [-0.6572616]
# 30    200RZBD07A-6709O
# Name: sku, dtype: object [-0.31498107]
# 31    200RZBD07A-28020
# Name: sku, dtype: object [1.13519035]
# 32    200RZBD21A-71001010
# Name: sku, dtype: object [-2.06343454]
# 33    200RZBD21A-6709
# Name: sku, dtype: object [-1.34815832]
# 34    200RZBD21A-53079
# Name: sku, dtype: object [-2.54649928]
# 35    200RZBD21A-9012
# Name: sku, dtype: object [-1.9176418]
# 36    200RZBD21A-2808
# Name: sku, dtype: object [-1.03400059]
# 37    200RZBD21A-203
# Name: sku, dtype: object [-1.01259407]
# 38    200RZBD21A-305
# Name: sku, dtype: object [-0.93728775]
# 39    200RZBD21A-406
# Name: sku, dtype: object [-0.60061624]
# 40    200RZBD21A-28012
# Name: sku, dtype: object [-0.88234882]
# 41    200RZBD21A-10014
# Name: sku, dtype: object [-1.41140115]
# 42    200RZBD21A-808R
# Name: sku, dtype: object [-0.24092111]
# 43    200RZBD21A-S808
# Name: sku, dtype: object [0.08187587]
# 44    200RZBD21A-S505
# Name: sku, dtype: object [-1.03502185]
# 45    200RZBD21A-12015
# Name: sku, dtype: object [0.69668555]
# 46    200RZBD21A-28020
# Name: sku, dtype: object [-1.81238111]
# 47    200OZEZ04A-508
# Name: sku, dtype: object [-1.68206934]
# 48    200OZEZ04A-8010
# Name: sku, dtype: object [-2.42429791]
# 49    200OZEZ04A-6709
# Name: sku, dtype: object [-1.65690652]
# 50    200OZEZ04A-406
# Name: sku, dtype: object [-0.59532473]
# 51    200OZEZ04A-3205
# Name: sku, dtype: object [-0.23978347]
# 52    200OZEZ04A-92012
# Name: sku, dtype: object [-0.54951245]
# 53    200OZEZ04A-2808
# Name: sku, dtype: object [-0.81320097]
# 54    200OZEZ04A-S808
# Name: sku, dtype: object [-0.47628116]
# 55    200OZEZ04A-53053R
# Name: sku, dtype: object [-1.22361443]
# 56    200OZEZ04A-10014
# Name: sku, dtype: object [-0.03937263]
# 57    200OZEZ04A-R808
# Name: sku, dtype: object [2.34092737]
# 58    200TAJT03-8010
# Name: sku, dtype: object [-2.30532391]
# 59    200TAJT03-606R
# Name: sku, dtype: object [-1.47577438]
# 60    200TAJT03-404R
# Name: sku, dtype: object [-1.17867528]
# 61    200TAJT03-609
# Name: sku, dtype: object [-2.14884151]
# 62    200TAJT03-2608
# Name: sku, dtype: object [-1.14698631]
# 63    200TAJT03-9012
# Name: sku, dtype: object [-1.6909854]
# 64    200TAJT03-808R
# Name: sku, dtype: object [-0.71780698]
# 65    200TAJT03-508
# Name: sku, dtype: object [-2.38019096]
# 66    200TAJT03-406O
# Name: sku, dtype: object [-0.95299944]
# 67    200TAJT03-406
# Name: sku, dtype: object [-1.07821517]
# 68    200TAJT03-305
# Name: sku, dtype: object [-1.33896967]
# 69    200TAJT03-2304O
# Name: sku, dtype: object [-0.50903855]
# 70    200TAJT03-305O
# Name: sku, dtype: object [-0.96188317]
# 71    200TAJT03-26010
# Name: sku, dtype: object [-1.59517287]
# 72    200TAJT03-508O
# Name: sku, dtype: object [-0.17781987]
# 73    200TAJT03-26012
# Name: sku, dtype: object [-0.89558506]
# 74    200TAJT03-609O
# Name: sku, dtype: object [-2.25750372]
# 75    200TAJT03-808S
# Name: sku, dtype: object [-0.87575796]
# 76    200TAJT03-606S
# Name: sku, dtype: object [-1.24149173]
# 77    200TAJT03-8010O
# Name: sku, dtype: object [-2.51468401]
# 78    200TAJT03-10014
# Name: sku, dtype: object [-1.03876833]
# 79    200TAJT03-12015
# Name: sku, dtype: object [-0.10149883]
# 80    200TAJT03-9012O
# Name: sku, dtype: object [0.19427387]
# 81    200BDSM08A-76096
# Name: sku, dtype: object [-0.9243294]
# 82    200BDSM08A-508
# Name: sku, dtype: object [-1.06285582]
# 83    200BDSM08A-860116
# Name: sku, dtype: object [-0.86296917]
# 84    200BDSM08A-6709
# Name: sku, dtype: object [-1.02614021]
# 85    200BDSM08A-305
# Name: sku, dtype: object [-0.35906627]
# 86    200BDSM08A-208
# Name: sku, dtype: object [-1.22472401]
# 87    200BDSM08A-203
# Name: sku, dtype: object [-1.16310288]
# 88    200BDSM08A-406
# Name: sku, dtype: object [-0.22963545]
# 89    200BDSM08A-9012
# Name: sku, dtype: object [-1.11136572]
# 90    200BDSM08A-10014
# Name: sku, dtype: object [-2.03831502]
# 91    200BDSM08A-26012
# Name: sku, dtype: object [-1.15027657]
# 92    200BDSM08A-12015
# Name: sku, dtype: object [0.16979313]
# 93    200BDSM04A-508
# Name: sku, dtype: object [-0.84374865]
# 94    200BDSM04A-6709
# Name: sku, dtype: object [-1.15851651]
# 95    200BDSM04A-76096
# Name: sku, dtype: object [-0.71930354]
# 96    200BDSM04A-406
# Name: sku, dtype: object [-0.20309229]
# 97    200BDSM04A-860116
# Name: sku, dtype: object [-0.84522988]
# 98    200BDSM04A-305
# Name: sku, dtype: object [-0.24832758]
# 99    200BDSM04A-203
# Name: sku, dtype: object [-0.76833521]
# 100    200BDSM04A-9012
# Name: sku, dtype: object [-1.23047663]
# 101    200BDSM04A-208
# Name: sku, dtype: object [-1.27779309]
# 102    200BDSM04A-10014
# Name: sku, dtype: object [-0.86734109]
# 103    200BDSM04A-S76096
# Name: sku, dtype: object [0.82854802]
# 104    200BDSM04A-12015
# Name: sku, dtype: object [0.]
# 105    200BDSM04A-76076R
# Name: sku, dtype: object [-0.]
# 106    200HJFV01C-76096
# Name: sku, dtype: object [-1.53565796]
# 107    200HJFV01C-508
# Name: sku, dtype: object [-1.40722706]
# 108    200HJFV01C-203
# Name: sku, dtype: object [-1.53285562]
# 109    200HJFV01C-305
# Name: sku, dtype: object [-0.99928]
# 110    200HJFV01C-2608
# Name: sku, dtype: object [-0.89001974]
# 111    200HJFV01C-406
# Name: sku, dtype: object [-0.98285467]
# 112    200HJFV01C-609
# Name: sku, dtype: object [-1.57261383]
# 113    200HJFV01C-2606
# Name: sku, dtype: object [-0.63790426]
# 114    200HJFV01C-860116
# Name: sku, dtype: object [-0.98835966]
# 115    200HJFV01C-606R
# Name: sku, dtype: object [-1.14492994]
# 116    200HJFV01C-26012
# Name: sku, dtype: object [-0.39905934]
# 117    200HJFV01C-26010
# Name: sku, dtype: object [-1.45783463]
# 118    200HJFV01C-508O
# Name: sku, dtype: object [0.04534525]
# 119    200HJFV01C-808R
# Name: sku, dtype: object [-0.24439348]
# 120    200HJFV01C-S808
# Name: sku, dtype: object [-0.02978703]
# 121    200HJFV01C-S606
# Name: sku, dtype: object [-0.76056616]
# 122    200HJFV01C-76096O
# Name: sku, dtype: object [-3.84123853]
# 123    200HJFV01C-406O
# Name: sku, dtype: object [-1.15817388]
# 124    200HJFV01C-860116O
# Name: sku, dtype: object [-0.0918798]
# 125    200HJFV01C-10014
# Name: sku, dtype: object [0.]
# 126    200NCCL01-2608
# Name: sku, dtype: object [-0.73129761]
# 128    200NCCL01-508
# Name: sku, dtype: object [-2.33425509]
# 129    200NCCL01-8010
# Name: sku, dtype: object [-1.53896682]
# 130    200NCCL01-9012
# Name: sku, dtype: object [-1.22896537]
# 131    200NCCL01-26010
# Name: sku, dtype: object [-1.06681255]
# 132    200NCCL01-305
# Name: sku, dtype: object [-2.04016462]
# 133    200NCCL01-406
# Name: sku, dtype: object [-0.89357015]
# 134    200NCCL01-960136
# Name: sku, dtype: object [-0.95702875]
# 135    200NCCL01-26012
# Name: sku, dtype: object [-0.70520427]

# %% [markdown]
# ### Plot Revenue for "RZBDA16A-71001010"

# %%
import matplotlib.pyplot as plt
subset_data = sales_inner.loc[(sales_inner['code'] == 1)]
Revenue = sales_inner
Revenue['revenue'] = Revenue['avg_paid_price'] * Revenue['total_qty']
subset_data = Revenue.loc[(Revenue['code'] == 1)]
subset_data.head()
# Out:
#                      sku   full_date  total_qty  avg_list_price  \
# 75   200RZBD16A-71001010  2018-05-07        9.0           329.0
# 172  200RZBD16A-71001010  2018-05-08        5.0           329.0
# 413  200RZBD16A-71001010  2018-05-09       10.0           329.0
# 521  200RZBD16A-71001010  2018-05-10       14.0           329.0
# 696  200RZBD16A-71001010  2018-05-11       11.0           329.0
#
#      avg_discount_rate  avg_paid_price    logqty  logprice  code  revenue
# 75                0.49          167.67  2.197225  5.121998   1.0  1509.03
# 172               0.48          170.60  1.609438  5.139322   1.0   853.00
# 413               0.50          165.90  2.302585  5.111385   1.0  1659.00
# 521               0.48          172.50  2.639057  5.150397   1.0  2415.00
# 696               0.48          170.18  2.397895  5.136857   1.0  1871.98

# %%
subset_data.plot(kind='scatter',x='avg_paid_price',y='total_qty',color='red')
plt.show()

# %%
subset_data.plot(kind='scatter',x='total_qty',y='revenue',color='red')
plt.show()

# %%
subset_data = sales_inner.loc[(sales_inner['revenue'] <10000)]
subset_data.plot(kind='scatter',x='total_qty',y='revenue',color='red')
plt.show()

# %% [markdown]
# ### Revenue between 6K and 10K and total quantity < 45

# %%
subset_data = Revenue.loc[(Revenue['code'] == 1)]
subset_data = subset_data.loc[(sales_inner['revenue'] <10000)]
subset_data2 = subset_data.loc[(sales_inner['revenue'] >6000)]
subset_data3 = subset_data2.loc[(sales_inner['total_qty'] <45)]
subset_data3
# Out:
#                        sku   full_date  total_qty  avg_list_price  \
# 18253  200RZBD16A-71001010  2018-07-22       39.0           329.0
# 23481  200RZBD16A-71001010  2018-08-12       38.0           329.0
# 50012  200RZBD16A-71001010  2018-11-19       41.0           362.0
# 69620  200RZBD16A-71001010  2019-01-01       36.0           362.0
# 71889  200RZBD16A-71001010  2019-01-06       41.0           362.0
# 82311  200RZBD16A-71001010  2019-02-10       38.0           362.0
# 83576  200RZBD16A-71001010  2019-02-15       38.0           362.0
# 84105  200RZBD16A-71001010  2019-02-16       38.0           362.0
# 86044  200RZBD16A-71001010  2019-02-19       39.0           362.0
# 94108  200RZBD16A-71001010  2019-03-16       43.0           362.0
#
#        avg_discount_rate  avg_paid_price    logqty  logprice  code  revenue
# 18253               0.50          164.00  3.663562  5.099866   1.0  6396.00
# 23481               0.50          164.45  3.637586  5.102607   1.0  6249.10
# 50012               0.57          154.37  3.713572  5.039352   1.0  6329.17
# 69620               0.50          179.42  3.583519  5.189729   1.0  6459.12
# 71889               0.51          179.07  3.713572  5.187777   1.0  7341.87
# 82311               0.50          180.97  3.637586  5.198331   1.0  6876.86
# 83576               0.55          163.95  3.637586  5.099562   1.0  6230.10
# 84105               0.55          162.00  3.637586  5.087596   1.0  6156.00
# 86044               0.55          162.00  3.663562  5.087596   1.0  6318.00
# 94108               0.55          162.93  3.761200  5.093321   1.0  7005.99

# %%
subset_data3.plot(kind='scatter',x='total_qty',y='revenue',color='red')
plt.show()
